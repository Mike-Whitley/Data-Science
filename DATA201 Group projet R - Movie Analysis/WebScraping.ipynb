# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.2.0     ✔ purrr   0.3.2
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   0.8.3     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
install.packages("magrittr")
install.packages("purrr")
install.packages("glue")
install.packages("stringr")
# Out:
# The downloaded binary packages are in
# 	/var/folders/_n/9xvdch1x48x0yw5djjygcgsw0000gn/T//Rtmp9GAIOH/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/_n/9xvdch1x48x0yw5djjygcgsw0000gn/T//Rtmp9GAIOH/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/_n/9xvdch1x48x0yw5djjygcgsw0000gn/T//Rtmp9GAIOH/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/_n/9xvdch1x48x0yw5djjygcgsw0000gn/T//Rtmp9GAIOH/downloaded_packages

# %%
install.packages("rvest")
# Out:
# The downloaded binary packages are in
# 	/var/folders/_n/9xvdch1x48x0yw5djjygcgsw0000gn/T//Rtmp9GAIOH/downloaded_packages

# %%
remotes::install_github("dmi3kno/polite")
# Out:
# Skipping install of 'polite' from a github remote, the SHA1 (def0def9) has not changed since last install.
#   Use `force = TRUE` to force installation

# %%
install.packages("xml2")
# Out:
# The downloaded binary packages are in
# 	/var/folders/_n/9xvdch1x48x0yw5djjygcgsw0000gn/T//Rtmp9GAIOH/downloaded_packages

# %%
library(rvest) # rvest makes scraping easier
# Out:
# Loading required package: xml2
#
# Attaching package: ‘rvest’
#
# The following object is masked from ‘package:purrr’:
#
#     pluck
#
# The following object is masked from ‘package:readr’:
#
#     guess_encoding

# %%
library(polite) # polite is the "polite" version of rvest

# %%
movie_titles_url <- "https://www.the-numbers.com/movie/budgets/all" # this is the base url from where the scraping starts

page_title <- read_html(movie_titles_url)

# %%
table_nodes <- page_title %>% html_nodes("table") #get the main table that the data is stored in

# %%
table_nodes #check I got something
# Out:
# {xml_nodeset (1)}
# [1] <table>\n<tr>\n<th> </th>\n<th>Release Date</th>\n<th>Movie</th>\n<th>Pro ...

# %%
x <- table_nodes %>% 
    #html_nodes("tr") %>% #grabs the table rows  
    html_table() #used the function found in the code sample found here: https://rdrr.io/cran/rvest/man/html_table.html on line 9
    #This code will result in a dataframe from all the data in the table.

# %%
x
# Out:
# [[1]]
#         Release Date
# 1     1 Dec 17, 2009
# 2     2 May 20, 2011
# 3     3 Apr 23, 2019
# 4     4  Jun 5, 2019
# 5     5 Apr 22, 2015
# 6     6 Dec 13, 2017
# 7     7 Dec 16, 2015
# 8     8 Apr 25, 2018
# 9     9 May 24, 2007
# 10   10 Nov 13, 2017
# 11   11  Oct 6, 2015
# 12   12 Jul 19, 2012
# 13   13 May 23, 2018
# 14   14  Jul 2, 2013
# 15   15  Mar 7, 2012
# 16   16 Nov 24, 2010
# 17   17  May 4, 2007
# 18   18 Apr 22, 2016
# 19   19 Mar 23, 2016
# 20   20 Dec 11, 2012
# 21   21 Jul 15, 2009
# 22   22 Dec 13, 2013
# 23   23 Dec 10, 2014
# 24   24  Apr 7, 2017
# 25   25 Jun 28, 2006
# 26   26 May 23, 2017
# 27   27 Nov 14, 2008
# 28   28 Apr 25, 2012
# 29   29  Jul 7, 2006
# 30   30 Jun 14, 2013
# 31   31 May 16, 2008
# 32   32 Jul 17, 2020
# 33   33 Jun 27, 2012
# 34   34 Apr 11, 2012
# 35   35 Jun 20, 2017
# 36   36  Jun 9, 2015
# 37   37 May 23, 2012
# 38   38 Jun 24, 2009
# 39   39 Jun 25, 2014
# 40   40 May 26, 2006
# 41   41 May 14, 2010
# 42   42 Dec 14, 2005
# ...
